# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Error 502! La versión que has elegido probablemente no funciona.
# /workspaces/codespaces-jupyter/Minecraft-server
# /home/codespace/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Error: Unable to access jarfile forge.jar
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2etDorsPna4eGYUFfTFC7NKVMXc_38AVv1zjSPydrQD9fER1T" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	    mohist.jar	       spigot.yml
# banned-players.json  forge.jar	    ops.json	       user_jvm_args.txt
# bukkit.yml	     forge.jar.log  permissions.yml    usercache.json
# colabconfig.json     help.yml	    plugins	       usernamecache.json
# commands.yml	     libraries	    run.bat	       wepif.yml
# config		     logs	    run.sh	       whitelist.json
# crash-reports	     mods	    server-icon.png    world
# defaultconfigs	     mohist-config  server.properties
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 8.tcp.ngrok.io:17533
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 8504
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-657 but you have 1.20.1-580. The latest version has been built on 2024-04-09 12:46:09. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [02:31:38 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [02:31:38 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.5.0-1017-azure
# [02:31:40 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [02:31:40 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [02:31:41 INFO]: Found 50 dependencies adding them to mods collection
# [02:31:43 INFO]: Compatibility level set to JAVA_17
# [02:31:43 ERROR]: Mixin config fabric-item-group-api-v1.client.mixins.json does not specify "minVersion" property
# [02:31:43 INFO]: Propagating FML mod list to Fabric Loader
# [02:31:43 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [02:31:43 WARN]: Reference map 'naturalist-forge-forge-refmap.json' for naturalist.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:31:43 WARN]: Reference map 'simplyswords-common-refmap.json' for simplyswords-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:31:43 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:31:44 INFO]: Loaded configuration file for Canary: 123 options available, 0 override(s) found
# [02:31:44 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [02:31:45 ERROR]: Attempted to load class net/minecraft/client/MouseHandler for invalid dist DEDICATED_SERVER
# [02:31:45 WARN]: Error loading class: net/minecraft/client/MouseHandler (java.lang.RuntimeException: Attempted to load class net/minecraft/client/MouseHandler for invalid dist DEDICATED_SERVER)
# [02:31:45 WARN]: @Mixin target net.minecraft.client.MouseHandler was not found fabric-screen-api-v1.mixins.json:MouseMixin
# [02:31:45 ERROR]: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER
# [02:31:45 WARN]: Error loading class: net/minecraft/client/gui/screens/Screen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/Screen for invalid dist DEDICATED_SERVER)
# [02:31:45 WARN]: @Mixin target net.minecraft.client.gui.screens.Screen was not found fabric-screen-api-v1.mixins.json:ScreenAccessor
# [02:31:50 WARN]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [02:31:50 WARN]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [02:31:54 INFO]: Registered skill wom:wom:ender_step
# [02:31:54 INFO]: Registered skill epicfight:epicfight:basic_attack
# [02:31:54 INFO]: Registered skill epicfight:epicfight:air_attack
# [02:31:54 INFO]: Registered skill epicfight:epicfight:roll
# [02:31:54 INFO]: Registered skill epicfight:epicfight:step
# [02:31:54 INFO]: Registered skill epicfight:epicfight:knockdown_wakeup
# [02:31:54 INFO]: Registered skill wom:wom:ender_obscuris
# [02:31:54 INFO]: Registered skill wom:wom:dodge_master
# [02:31:54 INFO]: Registered skill wom:wom:precise_roll
# [02:31:54 INFO]: Registered skill wom:wom:shadow_step
# [02:31:54 INFO]: Registered skill epicfight:epicfight:guard
# [02:31:54 INFO]: Registered skill wom:wom:bull_charge
# [02:31:54 INFO]: Registered skill epicfight:epicfight:parrying
# [02:31:54 INFO]: Registered skill wom:wom:demon_mark_passive
# [02:31:54 INFO]: Registered skill epicfight:epicfight:impact_guard
# [02:31:54 INFO]: Registered skill epicfight:epicfight:berserker
# [02:31:54 INFO]: Registered skill epicfight:epicfight:death_harvest
# [02:31:54 INFO]: Registered skill wom:wom:torment_passive
# [02:31:54 INFO]: Registered skill epicfight:epicfight:emergency_escape
# [02:31:54 INFO]: Registered skill wom:wom:ruine_passive
# [02:31:54 INFO]: Registered skill wom:wom:lunar_echo_passive
# [02:31:54 INFO]: Registered skill epicfight:epicfight:endurance
# [02:31:54 INFO]: Registered skill epicfight:epicfight:forbidden_strength
# [02:31:54 INFO]: Registered skill wom:wom:satsujin_passive
# [02:31:54 INFO]: Registered skill wom:wom:solar_passive
# [02:31:54 INFO]: Registered skill epicfight:epicfight:hypervitality
# [02:31:54 INFO]: Registered skill epicfight:epicfight:stamina_pillager
# [02:31:54 INFO]: Registered skill wom:wom:charybdis
# [02:31:54 INFO]: Registered skill epicfight:epicfight:swordmaster
# [02:31:54 INFO]: Registered skill wom:wom:agony_plunge
# [02:31:54 INFO]: Registered skill epicfight:epicfight:technician
# [02:31:54 INFO]: Registered skill wom:wom:true_berserk
# [02:31:54 INFO]: Registered skill epicfight:epicfight:sweeping_edge
# [02:31:54 INFO]: Registered skill epicfight:epicfight:dancing_edge
# [02:31:54 INFO]: Registered skill wom:wom:plunder_perdition
# [02:31:54 INFO]: Registered skill epicfight:epicfight:the_guillotine
# [02:31:54 INFO]: Registered skill epicfight:epicfight:grasping_spire
# [02:31:54 INFO]: Registered skill epicfight:epicfight:heartpiercer
# [02:31:54 INFO]: Registered skill wom:wom:sakura_state
# [02:31:54 INFO]: Registered skill epicfight:epicfight:steel_whirlwind
# [02:31:54 INFO]: Registered skill epicfight:epicfight:battojutsu
# [02:31:54 INFO]: Registered skill epicfight:epicfight:battojutsu_passive
# [02:31:54 INFO]: Registered skill epicfight:epicfight:rushing_tempo
# [02:31:54 INFO]: Registered skill wom:wom:ender_blast
# [02:31:54 INFO]: Registered skill epicfight:epicfight:relentless_combo
# [02:31:54 INFO]: Registered skill wom:wom:ender_fusion
# [02:31:54 INFO]: Registered skill epicfight:epicfight:liechtenauer
# [02:31:54 INFO]: Registered skill epicfight:epicfight:sharp_stab
# [02:31:54 INFO]: Registered skill epicfight:epicfight:eviscerate
# [02:31:54 INFO]: Registered skill wom:wom:demonic_ascension
# [02:31:54 INFO]: Registered skill wom:wom:regierung
# [02:31:54 INFO]: Registered skill wom:wom:lunar_eclipse
# [02:31:54 INFO]: Registered skill wom:wom:solar_arcano
# [02:31:54 INFO]: Registered skill wom:wom:counter_attack
# [02:31:54 INFO]: Registered skill wom:wom:perfect_bulwark
# [02:31:54 INFO]: Registered skill wom:wom:vengeful_parry
# [02:31:54 INFO]: Registered skill wom:wom:arrow_tenacity
# [02:31:54 INFO]: Registered skill wom:wom:pain_anticipation
# [02:31:54 INFO]: Registered skill wom:wom:latent_retribution
# [02:31:54 INFO]: Registered skill wom:wom:vampirize
# [02:31:54 INFO]: Registered skill wom:wom:critical_knowledge
# [02:31:54 INFO]: Registered skill wom:wom:heart_shield
# [02:31:54 INFO]: Registered skill wom:wom:mindset
# [02:31:54 INFO]: Registered skill wom:wom:adrenaline
# [02:31:54 INFO]: Registered skill wom:wom:dancing_blade
# [02:31:54 INFO]: Registered skill wom:wom:meditation
# [02:31:54 INFO]: Registered skill epicfight:epicfight:blade_rush
# [02:31:54 INFO]: Registered skill epicfight:epicfight:wrathful_lighting
# [02:31:54 INFO]: Registered skill epicfight:epicfight:tsunami
# [02:31:54 INFO]: Registered skill epicfight:epicfight:everlasting_allegiance
# [02:31:54 INFO]: Registered skill epicfight:epicfight:meteor_slam
# [02:31:54 INFO]: Registered skill epicfight:epicfight:revelation
# [02:31:54 INFO]: Registered skill epicfight:epicfight:demolition_leap
# [02:31:54 INFO]: Registered skill epicfight:epicfight:phantom_ascent
# [02:31:54 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [02:31:54 INFO]: MinecraftForge v47.2.20 Initialized
# [02:31:54 INFO]: NeoForge v47.2.20 Initialized
# [02:31:54 INFO]: Mohist mod loading.....
# [02:31:54 INFO]: EventDispatcherRegistry initialized
# [02:31:55 INFO]: Kotlin For Forge Enabled!
# [02:31:55 INFO]: Registering C2S receiver with id architectury:sync_ids
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [02:31:58 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [02:31:58 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [02:31:58 INFO]: Registered region regions_unexplored:primary to index 1 for type OVERWORLD
# [02:31:58 INFO]: Registered region regions_unexplored:secondary to index 2 for type OVERWORLD
# [02:31:58 INFO]: Registered region regions_unexplored:nether to index 1 for type NETHER
# [02:31:58 INFO]: Start animation registration of wom
# [02:31:58 INFO]: Assigned animation id 0 to biped/living/eating
# [02:31:58 INFO]: Assigned animation id 1 to biped/living/biped_hit_extra_long
# [02:31:58 INFO]: Assigned animation id 2 to biped/skill/kick
# [02:31:58 INFO]: Assigned animation id 3 to biped/skill/dodgemaster_back
# [02:31:58 INFO]: Assigned animation id 4 to biped/skill/dodgemaster_left
# [02:31:58 INFO]: Assigned animation id 5 to biped/skill/dodgemaster_right
# [02:31:58 INFO]: Assigned animation id 6 to biped/skill/enderstep_forward
# [02:31:58 INFO]: Assigned animation id 7 to biped/skill/enderstep_backward
# [02:31:58 INFO]: Assigned animation id 8 to biped/skill/enderstep_left
# [02:31:58 INFO]: Assigned animation id 9 to biped/skill/enderstep_right
# [02:31:58 INFO]: Assigned animation id 10 to biped/skill/ender_obscuris
# [02:31:58 INFO]: Assigned animation id 11 to biped/skill/mob_ender_obscuris
# [02:31:58 INFO]: Assigned animation id 12 to biped/skill/shadow_step_forward
# [02:31:58 INFO]: Assigned animation id 13 to biped/skill/shadow_step_backward
# [02:31:58 INFO]: Assigned animation id 14 to biped/skill/mob_shadow_step_forward
# [02:31:58 INFO]: Assigned animation id 15 to biped/skill/mob_shadow_step_backward
# [02:31:58 INFO]: Assigned animation id 16 to biped/skill/bull_charge
# [02:31:58 INFO]: Assigned animation id 17 to biped/skill/roll_forward
# [02:31:58 INFO]: Assigned animation id 18 to biped/skill/roll_backward
# [02:31:58 INFO]: Assigned animation id 19 to biped/skill/roll_left
# [02:31:58 INFO]: Assigned animation id 20 to biped/skill/roll_right
# [02:31:58 INFO]: Assigned animation id 21 to biped/skill/meditation_siting
# [02:31:58 INFO]: Assigned animation id 22 to biped/skill/meditation_breathing
# [02:31:58 INFO]: Assigned animation id 23 to biped/combat/agony_auto_1
# [02:31:58 INFO]: Assigned animation id 24 to biped/combat/agony_auto_2
# [02:31:58 INFO]: Assigned animation id 25 to biped/combat/agony_auto_3
# [02:31:58 INFO]: Assigned animation id 26 to biped/combat/agony_auto_4
# [02:31:58 INFO]: Assigned animation id 27 to biped/combat/agony_clawstrike
# [02:31:58 INFO]: Assigned animation id 28 to biped/combat/agony_counter
# [02:31:58 INFO]: Assigned animation id 29 to biped/combat/agony_airslash
# [02:31:58 INFO]: Assigned animation id 30 to biped/living/agony_idle
# [02:31:58 INFO]: Assigned animation id 31 to biped/living/agony_run
# [02:31:58 INFO]: Assigned animation id 32 to biped/living/agony_walk
# [02:31:58 INFO]: Assigned animation id 33 to biped/skill/agony_guard
# [02:31:58 INFO]: Assigned animation id 34 to biped/skill/agony_guard_hit1
# [02:31:58 INFO]: Assigned animation id 35 to biped/skill/agony_guard_hit2
# [02:31:58 INFO]: Assigned animation id 36 to biped/skill/agony_plunge_forward
# [02:31:58 INFO]: Assigned animation id 37 to biped/skill/agony_plunge_forward_x
# [02:31:58 INFO]: Assigned animation id 38 to biped/combat/ruine_auto_1
# [02:31:58 INFO]: Assigned animation id 39 to biped/combat/ruine_auto_2
# [02:31:58 INFO]: Assigned animation id 40 to biped/combat/ruine_auto_3
# [02:31:58 INFO]: Assigned animation id 41 to biped/combat/ruine_auto_4
# [02:31:58 INFO]: Assigned animation id 42 to biped/skill/ruine_counterattack
# [02:31:58 INFO]: Assigned animation id 43 to biped/combat/ruine_dash
# [02:31:58 INFO]: Assigned animation id 44 to biped/combat/ruine_comet
# [02:31:58 INFO]: Assigned animation id 45 to biped/skill/ruine_block
# [02:31:58 INFO]: Assigned animation id 46 to biped/living/ruine_idle
# [02:31:58 INFO]: Assigned animation id 47 to biped/living/ruine_boosted_idle
# [02:31:58 INFO]: Assigned animation id 48 to biped/living/ruine_run
# [02:31:58 INFO]: Assigned animation id 49 to biped/living/ruine_walk
# [02:31:58 INFO]: Assigned animation id 50 to biped/living/ruine_boosted_walk
# [02:31:58 INFO]: Assigned animation id 51 to biped/skill/ruine_plunder
# [02:31:58 INFO]: Assigned animation id 52 to biped/skill/ruine_expiation
# [02:31:58 INFO]: Assigned animation id 53 to biped/skill/ruine_redemption
# [02:31:58 INFO]: Assigned animation id 54 to biped/combat/torment_auto_1
# [02:31:58 INFO]: Assigned animation id 55 to biped/combat/torment_auto_2
# [02:31:58 INFO]: Assigned animation id 56 to biped/combat/torment_auto_3
# [02:31:58 INFO]: Assigned animation id 57 to biped/combat/torment_auto_4
# [02:31:58 INFO]: Assigned animation id 58 to biped/combat/torment_dash
# [02:31:58 INFO]: Assigned animation id 59 to biped/combat/torment_airslam
# [02:31:58 INFO]: Assigned animation id 60 to biped/living/torment_idle
# [02:31:58 INFO]: Assigned animation id 61 to biped/living/torment_run
# [02:31:58 INFO]: Assigned animation id 62 to biped/living/torment_walk
# [02:31:58 INFO]: Assigned animation id 63 to biped/living/torment_charge
# [02:31:58 INFO]: Assigned animation id 64 to biped/combat/torment_charged_attack_1
# [02:31:58 INFO]: Assigned animation id 65 to biped/combat/torment_charged_attack_2
# [02:31:58 INFO]: Assigned animation id 66 to biped/combat/torment_charged_attack_3
# [02:31:58 INFO]: Assigned animation id 67 to biped/living/torment_berserk_idle
# [02:31:58 INFO]: Assigned animation id 68 to biped/skill/torment_berserk_auto_1
# [02:31:58 INFO]: Assigned animation id 69 to biped/skill/torment_berserk_auto_2
# [02:31:58 INFO]: Assigned animation id 70 to biped/skill/torment_berserk_dash
# [02:31:58 INFO]: Assigned animation id 71 to biped/skill/torment_berserk_airslam
# [02:31:58 INFO]: Assigned animation id 72 to biped/skill/torment_berserk_convert
# [02:31:58 INFO]: Assigned animation id 73 to biped/living/torment_berserk_run
# [02:31:58 INFO]: Assigned animation id 74 to biped/living/torment_berserk_walk
# [02:31:58 INFO]: Assigned animation id 75 to biped/combat/katana_sheathed_auto_1
# [02:31:58 INFO]: Assigned animation id 76 to biped/combat/katana_sheathed_auto_2
# [02:31:58 INFO]: Assigned animation id 77 to biped/combat/katana_sheathed_auto_3
# [02:31:58 INFO]: Assigned animation id 78 to biped/combat/katana_sheathed_dash
# [02:31:58 INFO]: Assigned animation id 79 to biped/combat/katana_sheathed_dash
# [02:31:58 INFO]: Assigned animation id 80 to biped/combat/katana_sheathed_counter
# [02:31:58 INFO]: Assigned animation id 81 to biped/living/katana_sheathe
# [02:31:58 INFO]: Assigned animation id 82 to biped/living/katana_sheathed_idle
# [02:31:58 INFO]: Assigned animation id 83 to biped/living/katana_sheathed_run
# [02:31:58 INFO]: Assigned animation id 84 to biped/combat/katana_auto_1
# [02:31:58 INFO]: Assigned animation id 85 to biped/combat/katana_auto_2
# [02:31:58 INFO]: Assigned animation id 86 to biped/combat/katana_auto_3
# [02:31:58 INFO]: Assigned animation id 87 to biped/combat/katana_dash
# [02:31:58 INFO]: Assigned animation id 88 to biped/combat/katana_tsukuyomi
# [02:31:58 INFO]: Assigned animation id 89 to biped/living/katana_idle
# [02:31:58 INFO]: Assigned animation id 90 to biped/living/katana_walk
# [02:31:58 INFO]: Assigned animation id 91 to biped/living/katana_run
# [02:31:58 INFO]: Assigned animation id 92 to biped/skill/katana_guard
# [02:31:58 INFO]: Assigned animation id 93 to biped/skill/katana_guard_hit
# [02:31:58 INFO]: Assigned animation id 94 to biped/skill/katana_fatal_draw
# [02:31:58 INFO]: Assigned animation id 95 to biped/skill/katana_fatal_draw_second
# [02:31:58 INFO]: Assigned animation id 96 to biped/skill/katana_fatal_draw_dash
# [02:31:58 INFO]: Assigned animation id 97 to biped/skill/katana_sakura_timed_slash
# [02:31:58 INFO]: Assigned animation id 98 to biped/combat/enderblaster_onehand_auto_1
# [02:31:58 INFO]: Assigned animation id 99 to biped/combat/enderblaster_onehand_auto_2
# [02:31:58 INFO]: Assigned animation id 100 to biped/combat/enderblaster_onehand_auto_3
# [02:31:58 INFO]: Assigned animation id 101 to biped/combat/enderblaster_onehand_auto_4
# [02:31:58 INFO]: Assigned animation id 102 to biped/combat/enderblaster_onehand_dash
# [02:31:58 INFO]: Assigned animation id 103 to biped/combat/enderblaster_onehand_jumpkick
# [02:31:58 INFO]: Assigned animation id 104 to biped/skill/enderblaster_onehand_shoot_1
# [02:31:58 INFO]: Assigned animation id 105 to biped/skill/enderblaster_onehand_shoot_2
# [02:31:58 INFO]: Assigned animation id 106 to biped/skill/enderblaster_onehand_shoot_2_forward
# [02:31:58 INFO]: Assigned animation id 107 to biped/skill/enderblaster_onehand_shoot_2_left
# [02:31:58 INFO]: Assigned animation id 108 to biped/skill/enderblaster_onehand_shoot_2_right
# [02:31:58 INFO]: Assigned animation id 109 to biped/skill/enderblaster_onehand_shoot_3
# [02:31:58 INFO]: Assigned animation id 110 to biped/skill/enderblaster_onehand_airshoot
# [02:31:58 INFO]: Assigned animation id 111 to biped/skill/enderblaster_onehand_shoot_dash
# [02:31:58 INFO]: Assigned animation id 112 to biped/living/enderblaster_onehand_idle
# [02:31:58 INFO]: Assigned animation id 113 to biped/living/enderblaster_onehand_walk
# [02:31:58 INFO]: Assigned animation id 114 to biped/living/enderblaster_onehand_run
# [02:31:58 INFO]: Assigned animation id 115 to biped/skill/enderblaster_onehand_aiming
# [02:31:58 INFO]: Assigned animation id 116 to biped/skill/enderblaster_onehand_shoot
# [02:31:58 INFO]: Assigned animation id 117 to biped/skill/enderblaster_onehand_shoot_layed
# [02:31:58 INFO]: Assigned animation id 118 to biped/skill/enderblaster_onehand_reload
# [02:31:58 INFO]: Assigned animation id 119 to biped/combat/enderblaster_onehand_auto_1
# [02:31:58 INFO]: Assigned animation id 120 to biped/combat/enderblaster_onehand_auto_2
# [02:31:58 INFO]: Assigned animation id 121 to biped/combat/enderblaster_onehand_auto_3
# [02:31:58 INFO]: Assigned animation id 122 to biped/combat/enderblaster_onehand_auto_4
# [02:31:58 INFO]: Assigned animation id 123 to biped/combat/enderblaster_twohand_tishnaw
# [02:31:58 INFO]: Assigned animation id 124 to biped/combat/enderblaster_twohand_dash
# [02:31:58 INFO]: Assigned animation id 125 to biped/skill/enderblaster_twohand_shoot_1
# [02:31:58 INFO]: Assigned animation id 126 to biped/skill/enderblaster_twohand_shoot_2
# [02:31:58 INFO]: Assigned animation id 127 to biped/skill/enderblaster_twohand_shoot_3
# [02:31:58 INFO]: Assigned animation id 128 to biped/skill/enderblaster_twohand_shoot_4
# [02:31:58 INFO]: Assigned animation id 129 to biped/skill/enderblaster_twohand_evade_left
# [02:31:58 INFO]: Assigned animation id 130 to biped/skill/enderblaster_twohand_evade_right
# [02:31:58 INFO]: Assigned animation id 131 to biped/skill/enderblaster_twohand_airshoot
# [02:31:58 INFO]: Assigned animation id 132 to biped/skill/enderblaster_twohand_shoot_dash
# [02:31:58 INFO]: Assigned animation id 133 to biped/living/enderblaster_twohand_idle
# [02:31:58 INFO]: Assigned animation id 134 to biped/living/enderblaster_twohand_walk
# [02:31:58 INFO]: Assigned animation id 135 to biped/skill/enderblaster_twohand_aiming
# [02:31:58 INFO]: Assigned animation id 136 to biped/skill/enderblaster_twohand_shoot_right
# [02:31:58 INFO]: Assigned animation id 137 to biped/skill/enderblaster_twohand_shoot_left
# [02:31:58 INFO]: Assigned animation id 138 to biped/skill/enderblaster_twohand_shoot_layed_right
# [02:31:58 INFO]: Assigned animation id 139 to biped/skill/enderblaster_twohand_shoot_layed_left
# [02:31:58 INFO]: Assigned animation id 140 to biped/skill/enderblaster_twohand_reload
# [02:31:58 INFO]: Assigned animation id 141 to biped/combat/staff_auto_1
# [02:31:58 INFO]: Assigned animation id 142 to biped/combat/staff_auto_2
# [02:31:58 INFO]: Assigned animation id 143 to biped/combat/staff_auto_3
# [02:31:58 INFO]: Assigned animation id 144 to biped/combat/staff_dash
# [02:31:58 INFO]: Assigned animation id 145 to biped/combat/staff_kingkong
# [02:31:58 INFO]: Assigned animation id 146 to biped/skill/staff_charybdisandscylla
# [02:31:58 INFO]: Assigned animation id 147 to biped/living/staff_idle
# [02:31:58 INFO]: Assigned animation id 148 to biped/living/staff_run
# [02:31:58 INFO]: Assigned animation id 149 to biped/combat/antitheus_agression
# [02:31:58 INFO]: Assigned animation id 150 to biped/combat/antitheus_guillotine
# [02:31:58 INFO]: Assigned animation id 151 to biped/combat/antitheus_auto_1
# [02:31:58 INFO]: Assigned animation id 152 to biped/combat/antitheus_auto_2
# [02:31:58 INFO]: Assigned animation id 153 to biped/combat/antitheus_auto_3
# [02:31:58 INFO]: Assigned animation id 154 to biped/combat/antitheus_auto_4
# [02:31:58 INFO]: Assigned animation id 155 to biped/living/antitheus_idle
# [02:31:58 INFO]: Assigned animation id 156 to biped/living/antitheus_run
# [02:31:58 INFO]: Assigned animation id 157 to biped/living/antitheus_walk
# [02:31:58 INFO]: Assigned animation id 158 to biped/skill/antitheus_aiming
# [02:31:58 INFO]: Assigned animation id 159 to biped/skill/antitheus_shoot
# [02:31:58 INFO]: Assigned animation id 160 to biped/skill/antitheus_pull
# [02:31:58 INFO]: Assigned animation id 161 to biped/skill/antitheus_ascension
# [02:31:58 INFO]: Assigned animation id 162 to biped/skill/antitheus_lapse
# [02:31:58 INFO]: Assigned animation id 163 to biped/skill/antitheus_ascended_auto_1
# [02:31:58 INFO]: Assigned animation id 164 to biped/skill/antitheus_ascended_auto_2
# [02:31:58 INFO]: Assigned animation id 165 to biped/skill/antitheus_ascended_auto_3
# [02:31:58 INFO]: Assigned animation id 166 to biped/skill/antitheus_ascended_deathfall
# [02:31:58 INFO]: Assigned animation id 167 to biped/skill/antitheus_ascended_blink
# [02:31:58 INFO]: Assigned animation id 168 to biped/skill/antitheus_ascended_blackhole
# [02:31:58 INFO]: Assigned animation id 169 to biped/living/antitheus_ascended_idle
# [02:31:58 INFO]: Assigned animation id 170 to biped/living/antitheus_ascended_run
# [02:31:58 INFO]: Assigned animation id 171 to biped/living/antitheus_ascended_walk
# [02:31:58 INFO]: Assigned animation id 172 to biped/living/herrscher_idle
# [02:31:58 INFO]: Assigned animation id 173 to biped/living/herrscher_walk
# [02:31:58 INFO]: Assigned animation id 174 to biped/living/herrscher_run
# [02:31:58 INFO]: Assigned animation id 175 to biped/skill/herrscher_guard
# [02:31:58 INFO]: Assigned animation id 176 to biped/skill/herrscher_guard_hit
# [02:31:58 INFO]: Assigned animation id 177 to biped/skill/herrscher_guard_parry
# [02:31:58 INFO]: Assigned animation id 178 to biped/skill/herrscher_trane
# [02:31:58 INFO]: Assigned animation id 179 to biped/combat/herrscher_auto_1
# [02:31:58 INFO]: Assigned animation id 180 to biped/combat/herrscher_auto_2
# [02:31:58 INFO]: Assigned animation id 181 to biped/combat/herrscher_auto_3
# [02:31:58 INFO]: Assigned animation id 182 to biped/combat/herrscher_befreiung
# [02:31:58 INFO]: Assigned animation id 183 to biped/combat/herrscher_ausrottung
# [02:31:58 INFO]: Assigned animation id 184 to biped/skill/gezets_auto_1
# [02:31:58 INFO]: Assigned animation id 185 to biped/skill/gezets_auto_2
# [02:31:58 INFO]: Assigned animation id 186 to biped/skill/gezets_auto_3
# [02:31:58 INFO]: Assigned animation id 187 to biped/skill/gezets_sprengkopf
# [02:31:58 INFO]: Assigned animation id 188 to biped/skill/gezets_krummen
# [02:31:58 INFO]: Assigned animation id 189 to biped/living/moonless_idle
# [02:31:58 INFO]: Assigned animation id 190 to biped/living/moonless_walk
# [02:31:58 INFO]: Assigned animation id 191 to biped/living/moonless_run
# [02:31:58 INFO]: Assigned animation id 192 to biped/combat/moonless_reversed_bypass
# [02:31:58 INFO]: Assigned animation id 193 to biped/combat/moonless_bypass
# [02:31:58 INFO]: Assigned animation id 194 to biped/combat/moonless_auto_1
# [02:31:58 INFO]: Assigned animation id 195 to biped/combat/moonless_auto_2
# [02:31:58 INFO]: Assigned animation id 196 to biped/combat/moonless_auto_3
# [02:31:58 INFO]: Assigned animation id 197 to biped/combat/moonless_auto_1_verso
# [02:31:58 INFO]: Assigned animation id 198 to biped/combat/moonless_auto_2_verso
# [02:31:58 INFO]: Assigned animation id 199 to biped/combat/moonless_auto_3_verso
# [02:31:58 INFO]: Assigned animation id 200 to biped/skill/moonless_lunar_echo
# [02:31:58 INFO]: Assigned animation id 201 to biped/skill/moonless_lunar_eclipse
# [02:31:58 INFO]: Assigned animation id 202 to biped/combat/moonless_crescent
# [02:31:58 INFO]: Assigned animation id 203 to biped/combat/moonless_fullmoon
# [02:31:58 INFO]: Assigned animation id 204 to biped/skill/moonless_guard
# [02:31:58 INFO]: Assigned animation id 205 to biped/skill/moonless_guard_hit_1
# [02:31:58 INFO]: Assigned animation id 206 to biped/skill/moonless_guard_hit_2
# [02:31:58 INFO]: Assigned animation id 207 to biped/skill/moonless_guard_hit_3
# [02:31:58 INFO]: Assigned animation id 208 to biped/combat/moonless_rewinder
# [02:31:58 INFO]: Assigned animation id 209 to biped/living/solar_idle
# [02:31:58 INFO]: Assigned animation id 210 to biped/living/solar_walk
# [02:31:58 INFO]: Assigned animation id 211 to biped/living/solar_run
# [02:31:58 INFO]: Assigned animation id 212 to biped/combat/solar_auto_1
# [02:31:58 INFO]: Assigned animation id 213 to biped/combat/solar_auto_2
# [02:31:58 INFO]: Assigned animation id 214 to biped/combat/solar_auto_3
# [02:31:58 INFO]: Assigned animation id 215 to biped/combat/solar_auto_4
# [02:31:58 INFO]: Assigned animation id 216 to biped/skill/solar_auto_1_polvora
# [02:31:58 INFO]: Assigned animation id 217 to biped/skill/solar_auto_2_polvora
# [02:31:58 INFO]: Assigned animation id 218 to biped/skill/solar_auto_3_polvora
# [02:31:58 INFO]: Assigned animation id 219 to biped/skill/solar_auto_4_polvora
# [02:31:58 INFO]: Assigned animation id 220 to biped/combat/solar_quemadura
# [02:31:58 INFO]: Assigned animation id 221 to biped/combat/solar_horno
# [02:31:58 INFO]: Start animation registration of epicfight
# [02:31:58 INFO]: Assigned animation id 0 to biped/living/idle
# [02:31:58 INFO]: Assigned animation id 1 to biped/living/walk
# [02:31:58 INFO]: Assigned animation id 2 to biped/living/fly
# [02:31:58 INFO]: Assigned animation id 3 to biped/living/creative_idle
# [02:31:58 INFO]: Assigned animation id 4 to biped/living/creative_fly
# [02:31:58 INFO]: Assigned animation id 5 to biped/living/creative_fly_backward
# [02:31:58 INFO]: Assigned animation id 6 to
# [02:31:58 INFO]: Assigned animation id 7 to biped/living/hold_crossbow
# [02:31:58 INFO]: Assigned animation id 8 to biped/living/hold_map_twohand
# [02:31:58 INFO]: Assigned animation id 9 to biped/living/hold_map_offhand
# [02:31:58 INFO]: Assigned animation id 10 to biped/living/hold_map_mainhand
# [02:31:58 INFO]: Assigned animation id 11 to biped/living/hold_map_twohand_move
# [02:31:58 INFO]: Assigned animation id 12 to biped/living/hold_map_offhand_move
# [02:31:58 INFO]: Assigned animation id 13 to biped/living/hold_map_mainhand_move
# [02:31:58 INFO]: Assigned animation id 14 to biped/living/run
# [02:31:58 INFO]: Assigned animation id 15 to biped/living/sneak
# [02:31:58 INFO]: Assigned animation id 16 to biped/living/swim
# [02:31:58 INFO]: Assigned animation id 17 to biped/living/float
# [02:31:58 INFO]: Assigned animation id 18 to biped/living/kneel
# [02:31:58 INFO]: Assigned animation id 19 to biped/living/fall
# [02:31:58 INFO]: Assigned animation id 20 to biped/living/mount
# [02:31:58 INFO]: Assigned animation id 21 to biped/living/sit
# [02:31:58 INFO]: Assigned animation id 22 to biped/living/dig
# [02:31:58 INFO]: Assigned animation id 23 to biped/living/dig_offhand
# [02:31:58 INFO]: Assigned animation id 24 to
# [02:31:58 INFO]: Assigned animation id 25 to biped/combat/bow_aim_mid
# [02:31:58 INFO]: Assigned animation id 26 to biped/combat/bow_shot_mid
# [02:31:58 INFO]: Assigned animation id 27 to biped/living/drink
# [02:31:58 INFO]: Assigned animation id 28 to biped/living/drink
# [02:31:58 INFO]: Assigned animation id 29 to biped/living/drink_offhand
# [02:31:58 INFO]: Assigned animation id 30 to biped/living/eat
# [02:31:58 INFO]: Assigned animation id 31 to biped/living/eat
# [02:31:58 INFO]: Assigned animation id 32 to biped/living/eat_offhand
# [02:31:58 INFO]: Assigned animation id 33 to biped/living/spyglass
# [02:31:58 INFO]: Assigned animation id 34 to biped/living/spyglass
# [02:31:58 INFO]: Assigned animation id 35 to biped/living/spyglass_offhand
# [02:31:58 INFO]: Assigned animation id 36 to biped/combat/crossbow_aim_mid
# [02:31:58 INFO]: Assigned animation id 37 to biped/combat/crossbow_shot_mid
# [02:31:58 INFO]: Assigned animation id 38 to biped/combat/crossbow_reload
# [02:31:58 INFO]: Assigned animation id 39 to biped/living/jump
# [02:31:58 INFO]: Assigned animation id 40 to biped/living/run_spear
# [02:31:58 INFO]: Assigned animation id 41 to biped/living/shield
# [02:31:58 INFO]: Assigned animation id 42 to biped/living/shield
# [02:31:58 INFO]: Assigned animation id 43 to biped/living/shield_mirror
# [02:31:58 INFO]: Assigned animation id 44 to biped/living/hold_greatsword
# [02:31:58 INFO]: Assigned animation id 45 to biped/living/hold_uchigatana_sheath
# [02:31:58 INFO]: Assigned animation id 46 to biped/living/hold_uchigatana
# [02:31:58 INFO]: Assigned animation id 47 to biped/living/hold_tachi
# [02:31:58 INFO]: Assigned animation id 48 to biped/living/hold_longsword
# [02:31:58 INFO]: Assigned animation id 49 to biped/living/hold_spear
# [02:31:58 INFO]: Assigned animation id 50 to biped/living/hold_dual
# [02:31:58 INFO]: Assigned animation id 51 to biped/living/hold_liechtenauer
# [02:31:58 INFO]: Assigned animation id 52 to biped/living/walk_greatsword
# [02:31:58 INFO]: Assigned animation id 53 to biped/living/walk_spear
# [02:31:58 INFO]: Assigned animation id 54 to biped/living/walk_uchigatana_sheath
# [02:31:58 INFO]: Assigned animation id 55 to biped/living/walk_uchigatana
# [02:31:58 INFO]: Assigned animation id 56 to biped/living/walk_twohand
# [02:31:58 INFO]: Assigned animation id 57 to biped/living/walk_longsword
# [02:31:58 INFO]: Assigned animation id 58 to biped/living/walk_liechtenauer
# [02:31:58 INFO]: Assigned animation id 59 to biped/living/run_greatsword
# [02:31:58 INFO]: Assigned animation id 60 to biped/living/run_uchigatana
# [02:31:58 INFO]: Assigned animation id 61 to biped/living/run_uchigatana_sheath
# [02:31:58 INFO]: Assigned animation id 62 to biped/living/run_dual
# [02:31:58 INFO]: Assigned animation id 63 to biped/living/run_longsword
# [02:31:58 INFO]: Assigned animation id 64 to biped/living/uchigatana_scrap
# [02:31:58 INFO]: Assigned animation id 65 to biped/living/liechtenauer_ready
# [02:31:58 INFO]: Assigned animation id 66 to biped/combat/hit_shield
# [02:31:58 INFO]: Assigned animation id 67 to biped/combat/hit_shield
# [02:31:58 INFO]: Assigned animation id 68 to biped/combat/hit_shield_mirror
# [02:31:58 INFO]: Assigned animation id 69 to biped/living/climb
# [02:31:58 INFO]: Assigned animation id 70 to biped/living/sleep
# [02:31:58 INFO]: Assigned animation id 71 to biped/combat/javelin_aim_mid
# [02:31:58 INFO]: Assigned animation id 72 to biped/combat/javelin_throw_mid
# [02:31:58 INFO]: Assigned animation id 73 to off_highest
# [02:31:58 INFO]: Assigned animation id 74 to off_middle
# [02:31:58 INFO]: Assigned animation id 75 to zombie/idle
# [02:31:58 INFO]: Assigned animation id 76 to zombie/walk
# [02:31:58 INFO]: Assigned animation id 77 to zombie/chase
# [02:31:58 INFO]: Assigned animation id 78 to creeper/idle
# [02:31:58 INFO]: Assigned animation id 79 to creeper/walk
# [02:31:58 INFO]: Assigned animation id 80 to enderman/idle
# [02:31:58 INFO]: Assigned animation id 81 to enderman/walk
# [02:31:58 INFO]: Assigned animation id 82 to enderman/rage_idle
# [02:31:58 INFO]: Assigned animation id 83 to enderman/rage_walk
# [02:31:58 INFO]: Assigned animation id 84 to wither_skeleton/walk
# [02:31:58 INFO]: Assigned animation id 85 to wither_skeleton/chase
# [02:31:58 INFO]: Assigned animation id 86 to wither_skeleton/idle
# [02:31:58 INFO]: Assigned animation id 87 to wither_skeleton/special_spawn
# [02:31:58 INFO]: Assigned animation id 88 to spider/idle
# [02:31:58 INFO]: Assigned animation id 89 to spider/crawl
# [02:31:58 INFO]: Assigned animation id 90 to iron_golem/idle
# [02:31:58 INFO]: Assigned animation id 91 to iron_golem/walk
# [02:31:58 INFO]: Assigned animation id 92 to hoglin/idle
# [02:31:58 INFO]: Assigned animation id 93 to hoglin/walk
# [02:31:58 INFO]: Assigned animation id 94 to illager/idle
# [02:31:58 INFO]: Assigned animation id 95 to illager/walk
# [02:31:58 INFO]: Assigned animation id 96 to illager/idle_aggressive
# [02:31:58 INFO]: Assigned animation id 97 to illager/chase
# [02:31:58 INFO]: Assigned animation id 98 to illager/spellcast
# [02:31:58 INFO]: Assigned animation id 99 to ravager/idle
# [02:31:58 INFO]: Assigned animation id 100 to ravager/walk
# [02:31:58 INFO]: Assigned animation id 101 to vex/idle
# [02:31:58 INFO]: Assigned animation id 102 to vex/flip
# [02:31:58 INFO]: Assigned animation id 103 to piglin/idle
# [02:31:58 INFO]: Assigned animation id 104 to piglin/walk
# [02:31:58 INFO]: Assigned animation id 105 to piglin/zombified_idle
# [02:31:58 INFO]: Assigned animation id 106 to piglin/zombified_walk
# [02:31:58 INFO]: Assigned animation id 107 to piglin/zombified_chase
# [02:31:58 INFO]: Assigned animation id 108 to piglin/celebrate1
# [02:31:58 INFO]: Assigned animation id 109 to piglin/celebrate2
# [02:31:58 INFO]: Assigned animation id 110 to piglin/celebrate3
# [02:31:58 INFO]: Assigned animation id 111 to piglin/admire
# [02:31:58 INFO]: Assigned animation id 112 to wither/idle
# [02:31:58 INFO]: Assigned animation id 113 to biped/skill/guard_spear
# [02:31:58 INFO]: Assigned animation id 114 to biped/skill/guard_sword
# [02:31:58 INFO]: Assigned animation id 115 to biped/skill/guard_dualsword
# [02:31:58 INFO]: Assigned animation id 116 to biped/skill/guard_greatsword
# [02:31:58 INFO]: Assigned animation id 117 to biped/skill/guard_uchigatana
# [02:31:58 INFO]: Assigned animation id 118 to biped/skill/guard_longsword
# [02:31:58 INFO]: Assigned animation id 119 to biped/skill/steel_whirlwind_charging
# [02:31:58 INFO]: Assigned animation id 120 to biped/skill/roll_forward
# [02:31:58 INFO]: Assigned animation id 121 to biped/skill/roll_backward
# [02:31:58 INFO]: Assigned animation id 122 to biped/skill/step_forward
# [02:31:58 INFO]: Assigned animation id 123 to biped/skill/step_backward
# [02:31:58 INFO]: Assigned animation id 124 to biped/skill/step_left
# [02:31:58 INFO]: Assigned animation id 125 to biped/skill/step_right
# [02:31:58 INFO]: Assigned animation id 126 to biped/skill/knockdown_wakeup_left
# [02:31:58 INFO]: Assigned animation id 127 to biped/skill/knockdown_wakeup_right
# [02:31:58 INFO]: Assigned animation id 128 to biped/skill/demolition_leap_charge
# [02:31:58 INFO]: Assigned animation id 129 to biped/skill/demolition_leap
# [02:31:58 INFO]: Assigned animation id 130 to biped/skill/phantom_ascent_forward
# [02:31:58 INFO]: Assigned animation id 131 to biped/skill/phantom_ascent_backward
# [02:31:58 INFO]: Assigned animation id 132 to biped/combat/fist_auto1
# [02:31:58 INFO]: Assigned animation id 133 to biped/combat/fist_auto2
# [02:31:58 INFO]: Assigned animation id 134 to biped/combat/fist_auto3
# [02:31:58 INFO]: Assigned animation id 135 to biped/combat/fist_dash
# [02:31:58 INFO]: Assigned animation id 136 to biped/combat/sword_auto1
# [02:31:58 INFO]: Assigned animation id 137 to biped/combat/sword_auto2
# [02:31:58 INFO]: Assigned animation id 138 to biped/combat/sword_auto3
# [02:31:58 INFO]: Assigned animation id 139 to biped/combat/sword_dash
# [02:31:58 INFO]: Assigned animation id 140 to biped/combat/greatsword_auto1
# [02:31:58 INFO]: Assigned animation id 141 to biped/combat/greatsword_auto2
# [02:31:58 INFO]: Assigned animation id 142 to biped/combat/greatsword_dash
# [02:31:58 INFO]: Assigned animation id 143 to biped/combat/spear_onehand_auto
# [02:31:58 INFO]: Assigned animation id 144 to biped/combat/spear_twohand_auto1
# [02:31:58 INFO]: Assigned animation id 145 to biped/combat/spear_twohand_auto2
# [02:31:58 INFO]: Assigned animation id 146 to biped/combat/spear_dash
# [02:31:58 INFO]: Assigned animation id 147 to 136
# [02:31:58 INFO]: Assigned animation id 148 to biped/combat/sword_auto4
# [02:31:58 INFO]: Assigned animation id 149 to biped/combat/tool_dash
# [02:31:58 INFO]: Assigned animation id 150 to biped/combat/axe_dash
# [02:31:58 INFO]: Assigned animation id 151 to biped/combat/sword_dual_auto1
# [02:31:58 INFO]: Assigned animation id 152 to biped/combat/sword_dual_auto2
# [02:31:58 INFO]: Assigned animation id 153 to biped/combat/sword_dual_auto3
# [02:31:58 INFO]: Assigned animation id 154 to biped/combat/sword_dual_dash
# [02:31:58 INFO]: Assigned animation id 155 to biped/combat/uchigatana_auto1
# [02:31:58 INFO]: Assigned animation id 156 to biped/combat/uchigatana_auto2
# [02:31:58 INFO]: Assigned animation id 157 to biped/combat/uchigatana_auto3
# [02:31:58 INFO]: Assigned animation id 158 to biped/combat/uchigatana_dash
# [02:31:58 INFO]: Assigned animation id 159 to biped/combat/uchigatana_sheath_auto
# [02:31:58 INFO]: Assigned animation id 160 to biped/combat/uchigatana_sheath_dash
# [02:31:58 INFO]: Assigned animation id 161 to biped/combat/axe_auto1
# [02:31:58 INFO]: Assigned animation id 162 to biped/combat/axe_auto2
# [02:31:58 INFO]: Assigned animation id 163 to biped/combat/longsword_auto1
# [02:31:58 INFO]: Assigned animation id 164 to biped/combat/longsword_auto2
# [02:31:58 INFO]: Assigned animation id 165 to biped/combat/longsword_auto3
# [02:31:58 INFO]: Assigned animation id 166 to biped/combat/longsword_dash
# [02:31:58 INFO]: Assigned animation id 167 to biped/combat/longsword_liechtenauer_auto1
# [02:31:58 INFO]: Assigned animation id 168 to biped/combat/longsword_liechtenauer_auto2
# [02:31:58 INFO]: Assigned animation id 169 to biped/combat/longsword_liechtenauer_auto3
# [02:31:58 INFO]: Assigned animation id 170 to biped/combat/tachi_auto1
# [02:31:58 INFO]: Assigned animation id 171 to biped/combat/tachi_auto2
# [02:31:58 INFO]: Assigned animation id 172 to biped/combat/tachi_auto3
# [02:31:58 INFO]: Assigned animation id 173 to biped/combat/tachi_dash
# [02:31:58 INFO]: Assigned animation id 174 to biped/combat/dagger_auto1
# [02:31:58 INFO]: Assigned animation id 175 to biped/combat/dagger_auto2
# [02:31:58 INFO]: Assigned animation id 176 to biped/combat/dagger_auto3
# [02:31:58 INFO]: Assigned animation id 177 to biped/combat/dagger_dash
# [02:31:58 INFO]: Assigned animation id 178 to biped/combat/dagger_dual_auto1
# [02:31:58 INFO]: Assigned animation id 179 to biped/combat/dagger_dual_auto2
# [02:31:58 INFO]: Assigned animation id 180 to biped/combat/dagger_dual_auto3
# [02:31:58 INFO]: Assigned animation id 181 to biped/combat/dagger_dual_auto4
# [02:31:58 INFO]: Assigned animation id 182 to biped/combat/dagger_dual_dash
# [02:31:58 INFO]: Assigned animation id 183 to biped/combat/trident_auto1
# [02:31:58 INFO]: Assigned animation id 184 to biped/combat/trident_auto2
# [02:31:58 INFO]: Assigned animation id 185 to biped/combat/trident_auto3
# [02:31:58 INFO]: Assigned animation id 186 to biped/combat/sword_airslash
# [02:31:58 INFO]: Assigned animation id 187 to biped/combat/sword_dual_airslash
# [02:31:58 INFO]: Assigned animation id 188 to biped/combat/uchigatana_airslash
# [02:31:58 INFO]: Assigned animation id 189 to biped/combat/uchigatana_sheath_airslash
# [02:31:58 INFO]: Assigned animation id 190 to biped/combat/spear_onehand_airslash
# [02:31:58 INFO]: Assigned animation id 191 to biped/combat/spear_twohand_airslash
# [02:31:58 INFO]: Assigned animation id 192 to biped/combat/longsword_airslash
# [02:31:58 INFO]: Assigned animation id 193 to biped/combat/greatsword_airslash
# [02:31:58 INFO]: Assigned animation id 194 to biped/combat/fist_airslash
# [02:31:58 INFO]: Assigned animation id 195 to biped/combat/dagger_airslash
# [02:31:58 INFO]: Assigned animation id 196 to 187
# [02:31:58 INFO]: Assigned animation id 197 to biped/combat/axe_airslash
# [02:31:58 INFO]: Assigned animation id 198 to biped/combat/sword_mount_attack
# [02:31:58 INFO]: Assigned animation id 199 to biped/combat/spear_mount_attack
# [02:31:58 INFO]: Assigned animation id 200 to biped/combat/mob_onehand1
# [02:31:58 INFO]: Assigned animation id 201 to biped/combat/mob_onehand2
# [02:31:58 INFO]: Assigned animation id 202 to biped/combat/mob_greatsword1
# [02:31:58 INFO]: Assigned animation id 203 to biped/combat/mob_tachi_special
# [02:31:58 INFO]: Assigned animation id 204 to biped/combat/mob_spear_onehand
# [02:31:58 INFO]: Assigned animation id 205 to biped/combat/mob_spear_twohand1
# [02:31:58 INFO]: Assigned animation id 206 to biped/combat/mob_spear_twohand2
# [02:31:58 INFO]: Assigned animation id 207 to biped/combat/mob_spear_twohand3
# [02:31:58 INFO]: Assigned animation id 208 to biped/combat/mob_sword_dual1
# [02:31:58 INFO]: Assigned animation id 209 to biped/combat/mob_sword_dual2
# [02:31:58 INFO]: Assigned animation id 210 to biped/combat/mob_sword_dual3
# [02:31:58 INFO]: Assigned animation id 211 to biped/combat/mob_longsword1
# [02:31:58 INFO]: Assigned animation id 212 to biped/combat/mob_longsword2
# [02:31:58 INFO]: Assigned animation id 213 to biped/combat/mob_uchigatana1
# [02:31:58 INFO]: Assigned animation id 214 to biped/combat/mob_uchigatana2
# [02:31:58 INFO]: Assigned animation id 215 to biped/combat/mob_uchigatana3
# [02:31:58 INFO]: Assigned animation id 216 to biped/combat/mob_dagger_onehand1
# [02:31:58 INFO]: Assigned animation id 217 to biped/combat/mob_dagger_onehand2
# [02:31:58 INFO]: Assigned animation id 218 to biped/combat/mob_dagger_onehand3
# [02:31:58 INFO]: Assigned animation id 219 to biped/combat/mob_dagger_twohand1
# [02:31:58 INFO]: Assigned animation id 220 to biped/combat/mob_dagger_twohand2
# [02:31:58 INFO]: Assigned animation id 221 to biped/combat/mob_throw
# [02:31:58 INFO]: Assigned animation id 222 to biped/skill/guard_sword_hit
# [02:31:58 INFO]: Assigned animation id 223 to biped/skill/guard_sword_hit_active1
# [02:31:58 INFO]: Assigned animation id 224 to biped/skill/guard_sword_hit_active2
# [02:31:58 INFO]: Assigned animation id 225 to biped/skill/guard_sword_hit_active3
# [02:31:58 INFO]: Assigned animation id 226 to biped/skill/guard_longsword_hit_active1
# [02:31:58 INFO]: Assigned animation id 227 to biped/skill/guard_longsword_hit_active2
# [02:31:58 INFO]: Assigned animation id 228 to biped/skill/guard_dualsword_hit
# [02:31:58 INFO]: Assigned animation id 229 to biped/skill/guard_break1
# [02:31:58 INFO]: Assigned animation id 230 to biped/skill/guard_break2
# [02:31:58 INFO]: Assigned animation id 231 to biped/skill/guard_longsword_hit
# [02:31:58 INFO]: Assigned animation id 232 to biped/skill/guard_spear_hit
# [02:31:58 INFO]: Assigned animation id 233 to biped/skill/guard_greatsword_hit
# [02:31:58 INFO]: Assigned animation id 234 to biped/skill/guard_uchigatana_hit
# [02:31:58 INFO]: Assigned animation id 235 to biped/skill/greatsword_slam
# [02:31:58 INFO]: Assigned animation id 236 to biped/skill/revelation_normal
# [02:31:58 INFO]: Assigned animation id 237 to biped/skill/revelation_twohand
# [02:31:58 INFO]: Assigned animation id 238 to biped/combat/hit_short
# [02:31:58 INFO]: Assigned animation id 239 to biped/combat/hit_long
# [02:31:58 INFO]: Assigned animation id 240 to biped/combat/hit_on_mount
# [02:31:58 INFO]: Assigned animation id 241 to biped/living/landing
# [02:31:58 INFO]: Assigned animation id 242 to biped/combat/knockdown
# [02:31:58 INFO]: Assigned animation id 243 to biped/living/death
# [02:31:58 INFO]: Assigned animation id 244 to creeper/hit_short
# [02:31:58 INFO]: Assigned animation id 245 to creeper/hit_long
# [02:31:58 INFO]: Assigned animation id 246 to creeper/death
# [02:31:58 INFO]: Assigned animation id 247 to enderman/hit_short
# [02:31:58 INFO]: Assigned animation id 248 to enderman/hit_long
# [02:31:58 INFO]: Assigned animation id 249 to enderman/neutralized
# [02:31:58 INFO]: Assigned animation id 250 to enderman/convert_rage
# [02:31:58 INFO]: Assigned animation id 251 to enderman/tp_kick1
# [02:31:58 INFO]: Assigned animation id 252 to enderman/tp_kick2
# [02:31:58 INFO]: Assigned animation id 253 to enderman/rush_kick
# [02:31:58 INFO]: Assigned animation id 254 to enderman/jump_kick
# [02:31:58 INFO]: Assigned animation id 255 to enderman/knee
# [02:31:58 INFO]: Assigned animation id 256 to enderman/kick_twice
# [02:31:58 INFO]: Assigned animation id 257 to enderman/grasp
# [02:31:58 INFO]: Assigned animation id 258 to enderman/death
# [02:31:58 INFO]: Assigned animation id 259 to enderman/teleport
# [02:31:58 INFO]: Assigned animation id 260 to dragon/idle
# [02:31:58 INFO]: Assigned animation id 261 to dragon/walk
# [02:31:58 INFO]: Assigned animation id 262 to dragon/fly
# [02:31:58 INFO]: Assigned animation id 263 to dragon/death
# [02:31:58 INFO]: Assigned animation id 264 to dragon/ground_to_fly
# [02:31:58 INFO]: Assigned animation id 265 to dragon/fly_to_ground
# [02:31:58 INFO]: Assigned animation id 266 to dragon/attack1
# [02:31:58 INFO]: Assigned animation id 267 to dragon/attack2
# [02:31:58 INFO]: Assigned animation id 268 to dragon/attack3
# [02:31:58 INFO]: Assigned animation id 269 to dragon/attack4
# [02:31:58 INFO]: Assigned animation id 270 to dragon/attack4_recovery
# [02:31:58 INFO]: Assigned animation id 271 to dragon/fireball
# [02:31:58 INFO]: Assigned animation id 272 to dragon/airstrike
# [02:31:58 INFO]: Assigned animation id 273 to dragon/backjump_prepare
# [02:31:58 INFO]: Assigned animation id 274 to dragon/backjump_move
# [02:31:58 INFO]: Assigned animation id 275 to dragon/backjump_recovery
# [02:31:58 INFO]: Assigned animation id 276 to dragon/crystal_link
# [02:31:58 INFO]: Assigned animation id 277 to dragon/neutralized
# [02:31:58 INFO]: Assigned animation id 278 to dragon/neutralized_recovery
# [02:31:58 INFO]: Assigned animation id 279 to spider/attack
# [02:31:58 INFO]: Assigned animation id 280 to spider/jump_attack
# [02:31:58 INFO]: Assigned animation id 281 to spider/hit
# [02:31:58 INFO]: Assigned animation id 282 to spider/neutralized
# [02:31:58 INFO]: Assigned animation id 283 to spider/death
# [02:31:58 INFO]: Assigned animation id 284 to iron_golem/attack1
# [02:31:58 INFO]: Assigned animation id 285 to iron_golem/attack2
# [02:31:58 INFO]: Assigned animation id 286 to iron_golem/attack3
# ...
# [03:34:02 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ ya me papie al warden
# [03:34:13 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ hay 71 personas y nosotros acarreamos el serv XD
# [03:34:21 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ XD
# [03:34:34 INFO]: [SMP🪐] Miembro Ravrs ⪼ WTF
# [03:34:38 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ q
# [03:34:39 INFO]: [SMP🪐] Miembro Ravrs ⪼ cuanto lleva el server?
# [03:34:54 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ desde que se reinicio como 4 dias creo
# [03:35:14 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ no we
# [03:35:14 INFO]: AshOficialMC issued server command: /tps
# [03:35:19 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ cuantos
# [03:35:20 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ paso mas de 1 semana
# [03:35:24 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ a
# [03:35:44 INFO]: AshOficialMC issued server command: /home casanew
# [03:36:34 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ Nacho voy a probar unas cosas, vuelvo despues
# [03:36:44 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ bueno
# [03:37:31 INFO]: Ravrs has made the advancement [Stone Age]
# [03:37:38 INFO]: AshOficialMC lost connection: Disconnected
# [03:37:38 INFO]: > Owner AshOficialMC Salio del server.
# [03:37:46 INFO]: Ravrs has made the advancement [Getting an Upgrade]
# [03:38:33 INFO]: [SMP🪐] Miembro Ravrs ⪼ es la primera vez que con mas de 100 mods el minecraft me va a 400 fps
# [03:38:46 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ enserio?
# [03:38:51 INFO]: [SMP🪐] Miembro Ravrs ⪼ sup
# [03:38:55 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ wah
# [03:39:23 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ imagina q yo esperaba q ni funcionara la pc
# [03:39:56 INFO]: Ravrs has made the advancement [Monster Hunter]
# [03:40:51 INFO]: Ravrs has made the advancement [advancements.alexsmobs.seagull_steal.title]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:47:26 INFO]: [SMP🪐] Miembro Ravrs ⪼ cual es el minearl mas valioso aqui?
# [03:47:41 INFO]: [Negativity] New Warning for Ravrs (100 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed Reliability: 85 [world: -14,158,178]
# [03:47:45 INFO]: [Negativity] New Warning for Ravrs (101 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed Reliability: 88 [world: -12,158,178]
# [03:47:48 INFO]: [Negativity] New Warning for Ravrs (101 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed Reliability: 79 [world: -13,160,181]
# [03:47:48 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ diria que los de las alex's caves
# [03:47:51 INFO]: [Negativity] New Warning for Ravrs (101 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed 2 times Reliability: 89 [world: -14,159,196]
# [03:48:03 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ porque son escasos
# [03:48:04 INFO]: [SMP🪐] Miembro Ravrs ⪼ encontre esmeralda y no lo puedo picar XD
# [03:48:10 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ xd
# [03:48:27 INFO]: [Negativity] New Warning for Ravrs (100 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed Reliability: 84 [world: -26,170,192]
# [03:48:28 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ con esmeralda podes hacer armadura
# [03:48:37 INFO]: [SMP🪐] Miembro Ravrs ⪼ enserio??
# [03:48:43 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ sip
# [03:48:51 INFO]: [SMP🪐] Miembro Ravrs ⪼ es mejor q la de diamante?
# [03:49:25 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ son lijeras
# [03:49:31 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ pero estan a la par
# [03:49:37 INFO]: [SMP🪐] Miembro Ravrs ⪼ oo
# [03:49:38 INFO]: [SMP🪐] Miembro Ravrs ⪼ okay
# [03:49:44 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ solo ocupas lagrimas de gasth
# [03:50:26 INFO]: Ravrs has made the advancement [Acquire Hardware]
# [03:50:30 INFO]: Ravrs has made the advancement [Isn't It Iron Pick]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [03:52:31 INFO]: Ravrs has made the advancement [Suit Up]
# [03:53:17 INFO]: [Negativity] New Warning for Ravrs (101 ms, UUID: 459dca36-2181-3c33-a124-4f16d4eebe09) seem to use Speed Reliability: 83 [world: -20,159,195]
# [03:53:23 INFO]: Nachus_GC issued server command: /gamemode spectator
# [03:53:28 INFO]: Nachus_GC issued server command: /tp Nachus_GC Ravrs
# [03:53:36 INFO]: Ravrs lost connection: Disconnected
# [03:53:36 INFO]: > Miembro Ravrs Salio del server.
# [03:54:56 INFO]: Nachus_GC issued server command: /gamemode creative
# [03:56:42 INFO]: Nachus_GC issued server command: /tp Nachus_GC 797.5 174 1413.5
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:03:18 INFO]: Nachus_GC issued server command: /tp Nachus_GC 555.0 63 -1731.0
# [04:03:25 WARN]: Nachus_GC moved too quickly! 2.6580718519925313,-9.670240888521747,0.1333612816049481
# [04:03:36 WARN]: UUID of added entity already exists: Drowned['Drowned'/15488, l='ServerLevel[world]', x=586.50, y=20.00, z=-1806.50]
# [04:03:38 WARN]: UUID of added entity already exists: Drowned['Drowned'/15586, l='ServerLevel[world]', x=585.50, y=25.00, z=-1806.50]
# [04:03:38 WARN]: UUID of added entity already exists: Drowned['Drowned'/15597, l='ServerLevel[world]', x=575.50, y=25.00, z=-1810.50]
# [04:03:51 WARN]: UUID of added entity already exists: Drowned['Drowned'/15687, l='ServerLevel[world]', x=580.50, y=25.00, z=-1806.50]
# [04:03:53 WARN]: UUID of added entity already exists: Drowned['Drowned'/15779, l='ServerLevel[world]', x=590.50, y=20.00, z=-1805.50]
# [04:04:06 INFO]: Nachus_GC issued server command: /tp Nachus_GC 1179.0 64 -2055.0
# [04:04:42 ERROR]: No key selector in MapLike[{event_delay:0,event_distance:0.0f,range:16,source:{source_entity:[I;672061792,-366263352,-1752079043,-405291646],type:"minecraft:entity",y_offset:0.36f}}]
# [04:04:42 ERROR]: No key selector in MapLike[{event_delay:0,event_distance:0.0f,range:16,source:{source_entity:[I;176865803,-972338229,-2060744252,-623071664],type:"minecraft:entity",y_offset:0.36f}}]
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:45 WARN]: Empty or non-existent pool: joshie:village/ocean/decor
# [04:04:47 INFO]: Nachus_GC issued server command: /tp Nachus_GC 1823.0 63 -2111.0
# [04:04:51 INFO]: Nachus_GC issued server command: /tp Nachus_GC 1108.0 63 -1891.0
# [04:04:54 INFO]: Nachus_GC has made the advancement [advancement.dungeons_arise.find_illager_corsair_or_illager_galley.title]
# [04:08:15 INFO]: Nachus_GC issued server command: /effect give Nachus_GC minecraft:health_boost infinite 23
# [04:08:15 INFO]: [Nachus_GC: Applied effect Health Boost to Nachus_GC]
# [04:08:29 INFO]: Nachus_GC issued server command: /effect give Nachus_GC minecraft:strength infinite 10
# [04:08:29 INFO]: [Nachus_GC: Applied effect Strength to Nachus_GC]
# [04:08:41 INFO]: Nachus_GC issued server command: /gamemode survival
# [04:08:54 INFO]: [Negativity] New Warning for Nachus_GC (207 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use ForceField Reliability: 100 [world: 1025,67,-1951]
# [04:09:16 INFO]: [Negativity] New Warning for Nachus_GC (207 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use ForceField Reliability: 100 [world: 1020,67,-1947]
# [04:09:26 INFO]: [Negativity] New Warning for Nachus_GC (207 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Fly 5 times Reliability: 97 [world: 1013,68,-1954]
# [04:10:43 INFO]: [Negativity] New Warning for Nachus_GC (206 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use ForceField Reliability: 100 [world: 1015,67,-1951]
# [04:11:04 INFO]: > Owner AshOficialMC Entro al servidor.
# [04:11:04 INFO]: AshOficialMC[/127.0.0.1:44614] logged in with entity id 21430 at ([world]797.8033721600691, 190.0, 1403.8151711327994)
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:11:45 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ volvi
# [04:12:13 INFO]: [Negativity] New Warning for Nachus_GC (202 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Fly 54 times Reliability: 100 [world: 1026,64,-1950]
# [04:12:14 INFO]: [Negativity] New Warning for Nachus_GC (202 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Fly 14 times Reliability: 100 [world: 1026,64,-1952]
# [04:12:15 INFO]: [Negativity] New Warning for Nachus_GC (202 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Fly 35 times Reliability: 100 [world: 1026,63,-1950]
# [04:12:57 INFO]: AshOficialMC issued server command: /lp group owner setdisplayname &9&lOwner
# [04:12:57 INFO]: [LP] LOG > (AshOficialMC) [G] (owner)
# [04:12:57 INFO]: [LP] LOG > setdisplayname &9&lOwner
# [04:13:18 INFO]: AshOficialMC issued server command: /lp group owner listmembers
# [04:13:26 INFO]: AshOficialMC issued server command: /lp group owner info
# [04:13:34 INFO]: AshOficialMC issued server command: /lp group owner setdisplayname
# [04:13:34 INFO]: [Negativity] New Warning for Nachus_GC (203 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use ForceField Reliability: 100 [world: 1019,67,-1951]
# [04:13:40 INFO]: AshOficialMC issued server command: /lp group owner setdisplayname Owner
# [04:13:40 INFO]: [LP] LOG > (AshOficialMC) [G] (owner)
# [04:13:40 INFO]: [LP] LOG > setdisplayname Owner
# [04:13:42 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ a
# [04:13:45 INFO]: AshOficialMC issued server command: /lp group owner info
# [04:13:59 INFO]: [Negativity] New Warning for Nachus_GC (205 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Fly 10 times Reliability: 100 [world: 1024,67,-1944]
# [04:14:06 INFO]: AshOficialMC issued server command: /lp group owner editor
# [04:16:00 INFO]: AshOficialMC issued server command: /lp applyedits 64SdUaG1ss
# [04:16:00 INFO]: [LP] LOG > (AshOficialMC) [G] (owner)
# [04:16:00 INFO]: [LP] LOG > webeditor add prefix.1.&9&lOwner &b true
# [04:16:00 INFO]: [LP] LOG > (AshOficialMC) [G] (owner)
# [04:16:00 INFO]: [LP] LOG > webeditor remove prefix.1.&6&lOwner &e true
# [04:16:55 INFO]: Nachus_GC issued server command: /gamemode creative
# [04:18:23 INFO]: Nachus_GC issued server command: /tp Nachus_GC -1098.0 72 -1195.0
# [04:18:44 WARN]: Nachus_GC moved too quickly! -6.327081073273575,0.0,-22.034832679066767
# [04:19:17 INFO]: Nachus_GC issued server command: /gamemode spectator
# [04:19:25 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ bro
# [04:19:30 INFO]: Nachus_GC issued server command: /gamemode creative
# [04:19:32 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ que pas
# [04:19:39 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ anono nada xd
# [04:19:45 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ me confundi algo
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:22:29 WARN]: Nachus_GC moved too quickly! 1283.171638540733,46.26590000152588,1137.810077335005
# [04:22:29 INFO]: Scanning for legacy world dragon fight...
# [04:22:29 INFO]: Found that the dragon has been killed in this world already.
# [04:22:45 INFO]: Nachus_GC has made the advancement [Who is Cutting Onions?]
# [04:23:04 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ tmre
# [04:23:13 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ no se si revivir al ender dragon o no
# [04:23:19 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ para sacar fotos
# [04:23:46 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ q dices
# [04:23:52 INFO]: Nachus_GC issued server command: /ping AshOficialMC
# [04:24:02 INFO]: Blood .[SMP🪐] Owner Nachus_GC ⪼ no bueno
# [04:27:00 INFO]: Nachus_GC has reached the goal [advancements.alexscaves.dreadbow.title]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [04:32:22 INFO]: Nachus_GC issued server command: /gamemode survival
# [04:32:25 INFO]: Nachus_GC has made the advancement [Third Time's the Charm]
# [04:32:54 INFO]: [Negativity] New Violation for Nachus_GC (291 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Speed 2 times Reliability: 84 [DIM1: 7,60,10]
# [04:34:34 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ sisis
# [04:34:40 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ revivelo ni es necesario
# [04:34:43 INFO]: Nachus_GC issued server command: /effect give Nachus_GC minecraft:strength infinite 200
# [04:34:43 INFO]: [Nachus_GC: Applied effect Strength to Nachus_GC]
# [04:35:09 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ voy a ir trabajando en la ultima Act que creo que el servidor recibira, vendran como 3 mods
# [04:35:24 INFO]: Blood .[SMP🪐] Owner AshOficialMC ⪼ pero son muy utiles y traeran cositas
# [04:35:31 INFO]: AshOficialMC lost connection: Disconnected
# [04:35:31 INFO]: > Owner AshOficialMC Salio del server.
# [04:36:10 INFO]: [Negativity] New Violation for Nachus_GC (211 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Speed 2 times Reliability: 67 [DIM1: 6,59,-15]
# [04:36:26 INFO]: [Negativity] New Violation for Nachus_GC (211 ms, UUID: 27cef4d1-62ad-3b6a-a0b1-375853a84c09) seem to use Speed 9 times Reliability: 87 [DIM1: -19,52,-31]
# [04:36:32 INFO]: Nachus_GC issued server command: /gamemode creative
# >
